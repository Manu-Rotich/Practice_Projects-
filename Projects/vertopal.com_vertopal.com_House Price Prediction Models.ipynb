# %% [markdown]
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# <span class="fc8 sc0">longitude</span><span class="_ _0"> </span><span
# class="fc8 sc0">latitude</span><span class="_ _0"> </span><span
# class="fc8 sc0">housing_median_age</span><span class="_ _0">
# </span><span class="fc8 sc0">t</span><span
# class="fc8 sc0">otal_r</span><span class="fc8 sc0">ooms</span><span
# class="_ _0"> </span><span class="fc8 sc0">t</span><span
# class="fc8 sc0">otal_bedr</span><span class="fc8 sc0">ooms</span><span
# class="_ _0"> </span><span class="fc8 sc0">population</span><span
# class="_ _0"> </span><span class="fc8 sc0">households</span><span
# class="_ _0"> </span><span class="fc8 sc0">median_inco</span>
#
# <span class="fc8 sc0">0</span><span class="_ _1"> </span><span
# class="ff2"><span class="fc8 sc0">-122.23</span><span class="_ _2">
# </span><span class="fc8 sc0">37.88</span><span class="_ _3">
# </span><span class="fc8 sc0">41</span><span class="_ _4"> </span><span
# class="fc8 sc0">880</span><span class="_ _5"> </span><span
# class="fc8 sc0">129.0</span><span class="_ _6"> </span><span
# class="fc8 sc0">322</span><span class="_ _7"> </span><span
# class="fc8 sc0">126</span><span class="_ _8"> </span><span
# class="fc8 sc0">8.3</span></span>
#
# <span class="fc8 sc0">1</span><span class="_ _1"> </span><span
# class="ff2"><span class="fc8 sc0">-122.22</span><span class="_ _2">
# </span><span class="fc8 sc0">37.86</span><span class="_ _3">
# </span><span class="fc8 sc0">21</span><span class="_ _9"> </span><span
# class="fc8 sc0">7099</span><span class="_ _8"> </span><span
# class="fc8 sc0">1106.0</span><span class="_ _a"> </span><span
# class="fc8 sc0">2401</span><span class="_ _b"> </span><span
# class="fc8 sc0">1138</span><span class="_ _8"> </span><span
# class="fc8 sc0">8.3</span></span>
#
# <span class="fc8 sc0">2</span><span class="_ _1"> </span><span
# class="ff2"><span class="fc8 sc0">-122.25</span><span class="_ _2">
# </span><span class="fc8 sc0">37.85</span><span class="_ _3">
# </span><span class="fc8 sc0">52</span><span class="_ _9"> </span><span
# class="fc8 sc0">1627</span><span class="_ _5"> </span><span
# class="fc8 sc0">280.0</span><span class="_ _6"> </span><span
# class="fc8 sc0">565</span><span class="_ _7"> </span><span
# class="fc8 sc0">259</span><span class="_ _8"> </span><span
# class="fc8 sc0">3.8</span></span>
#
# <span class="fc8 sc0">3</span><span class="_ _1"> </span><span
# class="ff2"><span class="fc8 sc0">-122.25</span><span class="_ _2">
# </span><span class="fc8 sc0">37.85</span><span class="_ _3">
# </span><span class="fc8 sc0">52</span><span class="_ _4"> </span><span
# class="fc8 sc0">919</span><span class="_ _5"> </span><span
# class="fc8 sc0">213.0</span><span class="_ _6"> </span><span
# class="fc8 sc0">413</span><span class="_ _7"> </span><span
# class="fc8 sc0">193</span><span class="_ _8"> </span><span
# class="fc8 sc0">4.0</span></span>
#
# <span class="fc8 sc0">4</span><span class="_ _1"> </span><span
# class="ff2"><span class="fc8 sc0">-122.25</span><span class="_ _2">
# </span><span class="fc8 sc0">37.84</span><span class="_ _3">
# </span><span class="fc8 sc0">52</span><span class="_ _9"> </span><span
# class="fc8 sc0">2535</span><span class="_ _5"> </span><span
# class="fc8 sc0">489.0</span><span class="_ _a"> </span><span
# class="fc8 sc0">1094</span><span class="_ _7"> </span><span
# class="fc8 sc0">514</span><span class="_ _8"> </span><span
# class="fc8 sc0">3.6</span></span>
#
# <span class="fc8 sc0">(18565, </span><span class="fc8 sc0">10)</span>
#
# <span class="fc8 sc0">\<class </span><span
# class="fc8 sc0">'pandas.core.frame.DataFrame'\></span>
#
# <span class="fc8 sc0">RangeIndex: </span><span class="fc8 sc0">18565
# </span><span class="fc8 sc0">entries, </span><span class="fc8 sc0">0
# </span><span class="fc8 sc0">to </span><span
# class="fc8 sc0">18564</span>
#
# <span class="fc8 sc0">Data </span><span class="fc8 sc0">columns
# </span><span class="fc8 sc0">(total </span><span class="fc8 sc0">10
# </span><span class="fc8 sc0">columns):</span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">\# </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">Column </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">Non-Null </span><span class="fc8 sc0">Count </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">Dtype </span><span
# class="fc8 sc0"> </span>
#
# <span class="fc8 sc0">--- </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">------ </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">-------------- </span><span class="fc8 sc0">
# </span><span class="fc8 sc0">----- </span><span class="fc8 sc0"> </span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">0 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">longitude </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">18565 </span><span
# class="fc8 sc0">non-null </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">float64</span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">1 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">latitude </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">18565 </span><span class="fc8 sc0">non-null </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">float64</span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">2 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">housing_median_age </span><span class="fc8 sc0">
# </span><span class="fc8 sc0">18565 </span><span class="fc8 sc0">non-null
# </span><span class="fc8 sc0"> </span><span class="fc8 sc0">int64
# </span><span class="fc8 sc0"> </span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">3 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">total_rooms </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">18565 </span><span
# class="fc8 sc0">non-null </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">int64 </span><span class="fc8 sc0"> </span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">4 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">total_bedrooms </span><span class="fc8 sc0">
# </span><span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">18376 </span><span class="fc8 sc0">non-null </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">float64</span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">5 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">population </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">18565 </span><span class="fc8 sc0">non-null </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">int64 </span><span
# class="fc8 sc0"> </span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">6 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">households </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">18565 </span><span class="fc8 sc0">non-null </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">int64 </span><span
# class="fc8 sc0"> </span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">7 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">median_income </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">18565 </span><span
# class="fc8 sc0">non-null </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">float64</span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">8 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">median_house_value </span><span class="fc8 sc0">
# </span><span class="fc8 sc0">18565 </span><span class="fc8 sc0">non-null
# </span><span class="fc8 sc0"> </span><span class="fc8 sc0">int64
# </span><span class="fc8 sc0"> </span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">9 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">ocean_proximity </span><span class="fc8 sc0">
# </span><span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">18565 </span><span
# class="fc8 sc0">non-null </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">object </span>
#
# <span class="fc8 sc0">dtypes: </span><span class="fc8 sc0">float64(4),
# </span><span class="fc8 sc0">int64(5), </span><span
# class="fc8 sc0">object(1)</span>
#
# <span class="fc8 sc0">memory </span><span class="fc8 sc0">usage:
# </span><span class="fc8 sc0">1.4+ </span><span class="fc8 sc0">MB</span>
#
# <span class="fc8 sc0">None</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[1\]:</span>
#
# import<span class="ff3 fc3"> pandas </span>as<span class="ff3 fc3">
# pd</span>
#
# import<span class="ff3 fc3"> numpy </span>as<span class="ff3 fc3">
# np</span>
#
# import<span class="ff3 fc3"> matplotlib.pyplot </span>as<span
# class="ff3 fc3"> plt</span>
#
# import<span class="ff3 fc3"> seaborn </span>as<span class="ff3 fc3">
# sns</span>
#
# from<span class="ff3 fc3"> sklearn </span>import<span class="ff3 fc3">
# preprocessing</span>
#
# from<span class="ff3 fc3"> sklearn.cluster </span>import<span
# class="ff3 fc3"> KMeans</span>
#
# import<span class="ff3 fc3"> warnings</span>
#
# from<span class="ff3 fc3"> sklearn.model_selection </span>import<span
# class="ff3 fc3"> train_test_split<span
# class="fc4">,</span>GridSearchCV</span>
#
# from<span class="ff3 fc3"> sklearn.metrics </span>import<span
# class="ff3 fc3"> mean_squared_error<span class="fc4">,</span>
# mean_absolute_error<span class="fc4">,</span> r2_score</span>
#
# from<span class="ff3 fc3"> sklearn.preprocessing </span>import<span
# class="ff3 fc3"> StandardScaler<span class="fc4">,</span>
# PolynomialFeatures</span>
#
# \# Ignore FutureWarnings
#
# warnings<span class="ff4 fc6">.</span>simplefilter<span
# class="fc4">(</span>action<span class="ff4 fc6">=</span><span
# class="fc7">'ignore'<span class="fc4">,</span></span> category<span
# class="ff4 fc6">=</span>FutureWarning<span class="fc4">)</span>
#
# \# Load dataset
#
# houseprice_df <span class="ff4 fc6">=</span> pd<span
# class="ff4 fc6">.</span>read_excel<span class="fc4">(<span
# class="fc7">'HousePrice_Dataset.xlsx'</span>)</span>
#
# houseprice_df<span class="ff4 fc6">.</span>head<span
# class="fc4">()</span>
#
# <span class="fc8 sc0">Out\[1\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[2\]:</span>
#
# \# Checking input data shape & info
#
# df <span class="ff4 fc6">=</span> houseprice_df<span
# class="ff4 fc6">.</span>copy<span class="fc4">()</span>
#
# print<span class="fc4">(</span>df<span
# class="ff4 fc6">.</span>shape<span class="fc4">)</span>
#
# print<span class="fc4">(</span>df<span class="ff4 fc6">.</span>info<span
# class="fc4">())</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[3\]:</span>
#
# #Checking for NULL values in Data
#
# df<span class="ff4 fc6">.</span>isnull<span class="fc4">()<span
# class="ff4 fc6">.</span></span>sum<span class="fc4">()</span>
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# <span class="fc8 sc0">longitude </span><span class="fc8 sc0">
# </span><span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">0</span>
#
# <span class="fc8 sc0">latitude </span><span class="fc8 sc0">
# </span><span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">0</span>
#
# <span class="fc8 sc0">housing_median_age </span><span class="fc8 sc0">
# </span><span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">0</span>
#
# <span class="fc8 sc0">total_rooms </span><span class="fc8 sc0">
# </span><span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">0</span>
#
# <span class="fc8 sc0">total_bedrooms </span><span class="fc8 sc0">
# </span><span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">189</span>
#
# <span class="fc8 sc0">population </span><span class="fc8 sc0">
# </span><span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">0</span>
#
# <span class="fc8 sc0">households </span><span class="fc8 sc0">
# </span><span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">0</span>
#
# <span class="fc8 sc0">median_income </span><span class="fc8 sc0">
# </span><span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">0</span>
#
# <span class="fc8 sc0">median_house_value </span><span class="fc8 sc0">
# </span><span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">0</span>
#
# <span class="fc8 sc0">ocean_proximity </span><span class="fc8 sc0">
# </span><span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">0</span>
#
# <span class="fc8 sc0">dtype: </span><span class="fc8 sc0">int64</span>
#
# <span class="fc8 sc0">\<class </span><span
# class="fc8 sc0">'pandas.core.frame.DataFrame'\></span>
#
# <span class="fc8 sc0">Int64Index: </span><span class="fc8 sc0">18376
# </span><span class="fc8 sc0">entries, </span><span class="fc8 sc0">0
# </span><span class="fc8 sc0">to </span><span
# class="fc8 sc0">18564</span>
#
# <span class="fc8 sc0">Data </span><span class="fc8 sc0">columns
# </span><span class="fc8 sc0">(total </span><span class="fc8 sc0">10
# </span><span class="fc8 sc0">columns):</span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">\# </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">Column </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">Non-Null </span><span class="fc8 sc0">Count </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">Dtype </span><span
# class="fc8 sc0"> </span>
#
# <span class="fc8 sc0">--- </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">------ </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">-------------- </span><span class="fc8 sc0">
# </span><span class="fc8 sc0">----- </span><span class="fc8 sc0"> </span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">0 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">longitude </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">18376 </span><span
# class="fc8 sc0">non-null </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">float64</span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">1 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">latitude </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">18376 </span><span class="fc8 sc0">non-null </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">float64</span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">2 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">housing_median_age </span><span class="fc8 sc0">
# </span><span class="fc8 sc0">18376 </span><span class="fc8 sc0">non-null
# </span><span class="fc8 sc0"> </span><span class="fc8 sc0">int64
# </span><span class="fc8 sc0"> </span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">3 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">total_rooms </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">18376 </span><span
# class="fc8 sc0">non-null </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">int64 </span><span class="fc8 sc0"> </span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">4 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">total_bedrooms </span><span class="fc8 sc0">
# </span><span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">18376 </span><span class="fc8 sc0">non-null </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">float64</span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">5 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">population </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">18376 </span><span class="fc8 sc0">non-null </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">int64 </span><span
# class="fc8 sc0"> </span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">6 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">households </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">18376 </span><span class="fc8 sc0">non-null </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">int64 </span><span
# class="fc8 sc0"> </span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">7 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">median_income </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">18376 </span><span
# class="fc8 sc0">non-null </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">float64</span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">8 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">median_house_value </span><span class="fc8 sc0">
# </span><span class="fc8 sc0">18376 </span><span class="fc8 sc0">non-null
# </span><span class="fc8 sc0"> </span><span class="fc8 sc0">int64
# </span><span class="fc8 sc0"> </span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0">9 </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">ocean_proximity </span><span class="fc8 sc0">
# </span><span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">18376 </span><span
# class="fc8 sc0">non-null </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">object </span>
#
# <span class="fc8 sc0">dtypes: </span><span class="fc8 sc0">float64(4),
# </span><span class="fc8 sc0">int64(5), </span><span
# class="fc8 sc0">object(1)</span>
#
# <span class="fc8 sc0">memory </span><span class="fc8 sc0">usage:
# </span><span class="fc8 sc0">1.5+ </span><span class="fc8 sc0">MB</span>
#
# <span class="fc8 sc0">0</span>
#
# <span class="fc8 sc0">longitude</span><span class="_ _c"> </span><span
# class="fc8 sc0">latitude</span><span class="_ _0"> </span><span
# class="fc8 sc0">housing_median_age</span><span class="_ _d">
# </span><span class="fc8 sc0">t</span><span
# class="fc8 sc0">otal_r</span><span class="fc8 sc0">ooms</span><span
# class="_ _0"> </span><span class="fc8 sc0">t</span><span
# class="fc8 sc0">otal_bedr</span><span class="fc8 sc0">ooms</span><span
# class="_ _e"> </span><span class="fc8 sc0">population</span><span
# class="_ _f"> </span><span class="fc8 sc0">househ</span>
#
# <span class="fc8 sc0">count</span><span class="_ _0"> </span><span
# class="ff2"><span class="fc8 sc0">18376.000000</span><span class="_ _0">
# </span><span class="fc8 sc0">18376.000000</span><span class="_ _10">
# </span><span class="fc8 sc0">18376.000000</span><span class="_ _0">
# </span><span class="fc8 sc0">18376.000000</span><span class="_ _1">
# </span><span class="fc8 sc0">18376.000000</span><span class="_ _0">
# </span><span class="fc8 sc0">18376.000000</span><span class="_ _0">
# </span><span class="fc8 sc0">18376.000</span></span>
#
# <span class="fc8 sc0">mean</span><span class="_ _11"> </span><span
# class="ff2"><span class="fc8 sc0">-119.571095</span><span class="_ _12">
# </span><span class="fc8 sc0">35.635164</span><span class="_ _13">
# </span><span class="fc8 sc0">28.605736</span><span class="_ _d">
# </span><span class="fc8 sc0">2635.302188</span><span class="_ _14">
# </span><span class="fc8 sc0">537.711199</span><span class="_ _d">
# </span><span class="fc8 sc0">1425.810786</span><span class="_ _15">
# </span><span class="fc8 sc0">499.37</span></span>
#
# <span class="fc8 sc0">st</span><span class="fc8 sc0">d</span><span
# class="_ _16"> </span><span class="ff2"><span
# class="fc8 sc0">2.003042</span><span class="_ _16"> </span><span
# class="fc8 sc0">2.137485</span><span class="_ _13"> </span><span
# class="fc8 sc0">12.570789</span><span class="_ _d"> </span><span
# class="fc8 sc0">2200.534974</span><span class="_ _14"> </span><span
# class="fc8 sc0">424.125849</span><span class="_ _d"> </span><span
# class="fc8 sc0">1143.481721</span><span class="_ _15"> </span><span
# class="fc8 sc0">384.514</span></span>
#
# <span class="fc8 sc0">min</span><span class="_ _11"> </span><span
# class="ff2"><span class="fc8 sc0">-124.350000</span><span class="_ _12">
# </span><span class="fc8 sc0">32.540000</span><span class="_ _17">
# </span><span class="fc8 sc0">1.000000</span><span class="_ _16">
# </span><span class="fc8 sc0">2.000000</span><span class="_ _18">
# </span><span class="fc8 sc0">2.000000</span><span class="_ _16">
# </span><span class="fc8 sc0">3.000000</span><span class="_ _16">
# </span><span class="fc8 sc0">2.000</span></span>
#
# <span class="fc8 sc0">25%</span><span class="_ _11"> </span><span
# class="ff2"><span class="fc8 sc0">-121.800000</span><span class="_ _12">
# </span><span class="fc8 sc0">33.930000</span><span class="_ _13">
# </span><span class="fc8 sc0">18.000000</span><span class="_ _d">
# </span><span class="fc8 sc0">1444.000000</span><span class="_ _14">
# </span><span class="fc8 sc0">295.000000</span><span class="_ _15">
# </span><span class="fc8 sc0">786.000000</span><span class="_ _15">
# </span><span class="fc8 sc0">280.000</span></span>
#
# <span class="fc8 sc0">50%</span><span class="_ _11"> </span><span
# class="ff2"><span class="fc8 sc0">-118.500000</span><span class="_ _12">
# </span><span class="fc8 sc0">34.260000</span><span class="_ _13">
# </span><span class="fc8 sc0">29.000000</span><span class="_ _d">
# </span><span class="fc8 sc0">2123.000000</span><span class="_ _14">
# </span><span class="fc8 sc0">434.000000</span><span class="_ _d">
# </span><span class="fc8 sc0">1165.500000</span><span class="_ _15">
# </span><span class="fc8 sc0">408.000</span></span>
#
# <span class="fc8 sc0">75%</span><span class="_ _11"> </span><span
# class="ff2"><span class="fc8 sc0">-118.010000</span><span class="_ _12">
# </span><span class="fc8 sc0">37.720000</span><span class="_ _13">
# </span><span class="fc8 sc0">37.000000</span><span class="_ _d">
# </span><span class="fc8 sc0">3137.000000</span><span class="_ _14">
# </span><span class="fc8 sc0">646.000000</span><span class="_ _d">
# </span><span class="fc8 sc0">1722.000000</span><span class="_ _15">
# </span><span class="fc8 sc0">603.000</span></span>
#
# <span class="fc8 sc0">max</span><span class="_ _11"> </span><span
# class="ff2"><span class="fc8 sc0">-114.310000</span><span class="_ _12">
# </span><span class="fc8 sc0">41.950000</span><span class="_ _13">
# </span><span class="fc8 sc0">52.000000</span><span class="_ _0">
# </span><span class="fc8 sc0">39320.000000</span><span class="_ _19">
# </span><span class="fc8 sc0">6445.000000</span><span class="_ _0">
# </span><span class="fc8 sc0">35682.000000</span><span class="_ _d">
# </span><span class="fc8 sc0">6082.000</span></span>
#
# <span class="fc8 sc0">Out\[3\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[4\]:</span>
#
# #Dropping NULL Values
#
# df <span class="ff4 fc6">=</span> df<span
# class="ff4 fc6">.</span>dropna<span class="fc4">()</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[5\]:</span>
#
# #Confirming dropna operation
#
# df<span class="ff4 fc6">.</span>info<span class="fc4">()</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[6\]:</span>
#
# #Checking for any duplicates
#
# df<span class="ff4 fc6">.</span>duplicated<span class="fc4">()<span
# class="ff4 fc6">.</span></span>sum<span class="fc4">()</span>
#
# <span class="fc8 sc0">Out\[6\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[7\]:</span>
#
# #Checking data composition for numerical features
#
# df<span class="ff4 fc6">.</span>describe<span class="fc4">()</span>
#
# <span class="fc8 sc0">Out\[7\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[8\]:</span>
#
# #Standardizing the numerical feilds.
#
# \# df\[\['housing_median_age'\]\] =
# preprocessing.scale(df\[\['housing_median_age'\]\]).astype('float6<span
# class="fc8 sc0">4</span>
#
# \# df\[\['total_rooms'\]\] =
# preprocessing.scale(df\[\['total_rooms'\]\]).astype('float64')
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# \# df\[\['total_bedrooms'\]\] =
# preprocessing.scale(df\[\['total_bedrooms'\]\]).astype('float64')
#
# \# df\[\['population'\]\] =
# preprocessing.scale(df\[\['population'\]\]).astype('float64')
#
# \# df\[\['households'\]\] =
# preprocessing.scale(df\[\['households'\]\]).astype('float64')
#
# \# df\[\['median_income'\]\] =
# preprocessing.scale(df\[\['median_income'\]\]).astype('float64')
#
# \# df\[\['median_house_value'\]\] =
# preprocessing.scale(df\[\['median_house_value'\]\]).astype('float6<span
# class="fc8 sc0">4</span>
#
# \# df.head()
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[9\]:</span>
#
# \# Correlation matrix
#
# figure1<span class="fc4">,</span> a <span class="ff4 fc6">=</span>
# plt<span class="ff4 fc6">.</span>subplots<span
# class="fc4">(</span>figsize<span class="ff4 fc6">=</span><span
# class="fc4">(<span class="fc9">12</span>,</span> <span
# class="fc9">10<span class="fc4">))</span></span>
#
# sns<span class="ff4 fc6">.</span>heatmap<span
# class="fc4">(</span>df<span class="ff4 fc6">.</span>corr<span
# class="fc4">(),</span> annot<span class="ff4 fc6">=<span
# class="fc2">True</span></span><span class="fc4">)</span>
#
# plt<span class="ff4 fc6">.</span>show<span class="fc4">()</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[10\]:</span>
#
# df<span class="ff4 fc6">=</span>df<span
# class="ff4 fc6">.</span>drop<span class="fc4">(\[<span
# class="fc7">'total_rooms'</span>,<span
# class="fc7">'total_bedrooms'</span>,<span
# class="fc7">'population'</span>\],</span> axis<span
# class="ff4 fc6">=</span><span class="fc9">1<span
# class="fc4">)</span></span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[11\]:</span>
#
# \# Correlation matrix
#
# figure1<span class="fc4">,</span> a <span class="ff4 fc6">=</span>
# plt<span class="ff4 fc6">.</span>subplots<span
# class="fc4">(</span>figsize<span class="ff4 fc6">=</span><span
# class="fc4">(<span class="fc9">12</span>,</span> <span
# class="fc9">10<span class="fc4">))</span></span>
#
# sns<span class="ff4 fc6">.</span>heatmap<span
# class="fc4">(</span>df<span class="ff4 fc6">.</span>corr<span
# class="fc4">(),</span> annot<span class="ff4 fc6">=<span
# class="fc2">True</span></span><span class="fc4">)</span>
#
# plt<span class="ff4 fc6">.</span>show<span class="fc4">()</span>
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# <span class="fc8 sc0">array(\['NEAR </span><span class="fc8 sc0">BAY',
# </span><span class="fc8 sc0">'\<1H </span><span class="fc8 sc0">OCEAN',
# </span><span class="fc8 sc0">'INLAND', </span><span
# class="fc8 sc0">'NEAR </span><span class="fc8 sc0">OCEAN', </span><span
# class="fc8 sc0">'ISLAND'\],</span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">dtype=object)</span>
#
# <span class="fc8 sc0">count</span><span class="_ _1a"> </span><span
# class="fc8 sc0">mean</span><span class="_ _1b"> </span><span
# class="fc8 sc0">st</span><span class="fc8 sc0">d</span><span
# class="_ _1c"> </span><span class="fc8 sc0">min</span><span
# class="_ _1d"> </span><span class="fc8 sc0">25%</span><span
# class="_ _1d"> </span><span class="fc8 sc0">50%</span><span
# class="_ _1d"> </span><span class="fc8 sc0">75%</span><span
# class="_ _1d"> </span><span class="fc8 sc0">max</span>
#
# <span class="fc8 sc0">ocean_pr</span><span class="fc8 sc0">o</span><span
# class="fc8 sc0">ximity</span>
#
# <span class="fc8 sc0">\<1H </span><span class="fc8 sc0">OCE</span><span
# class="fc8 sc0">AN</span><span class="_ _0"> </span><span
# class="ff2"><span class="fc8 sc0">8096.0</span><span class="_ _0">
# </span><span class="fc8 sc0">239973.465415</span><span class="_ _0">
# </span><span class="fc8 sc0">106101.457273</span><span class="_ _d">
# </span><span class="fc8 sc0">17500.0</span><span class="_ _0">
# </span><span class="fc8 sc0">164175.0</span><span class="_ _0">
# </span><span class="fc8 sc0">214750.0</span><span class="_ _0">
# </span><span class="fc8 sc0">289425.0</span><span class="_ _0">
# </span><span class="fc8 sc0">500001.0</span></span>
#
# <span class="fc8 sc0">INL</span><span class="fc8 sc0">AND</span><span
# class="_ _0"> </span><span class="ff2"><span
# class="fc8 sc0">5869.0</span><span class="_ _0"> </span><span
# class="fc8 sc0">124937.335492</span><span class="_ _d"> </span><span
# class="fc8 sc0">70783.931014</span><span class="_ _d"> </span><span
# class="fc8 sc0">14999.0</span><span class="_ _d"> </span><span
# class="fc8 sc0">77500.0</span><span class="_ _0"> </span><span
# class="fc8 sc0">108300.0</span><span class="_ _0"> </span><span
# class="fc8 sc0">148600.0</span><span class="_ _0"> </span><span
# class="fc8 sc0">500001.0</span></span>
#
# <span class="fc8 sc0">ISL</span><span class="fc8 sc0">AND</span><span
# class="_ _12"> </span><span class="ff2"><span
# class="fc8 sc0">5.0</span><span class="_ _0"> </span><span
# class="fc8 sc0">380440.000000</span><span class="_ _d"> </span><span
# class="fc8 sc0">80559.561816</span><span class="_ _0"> </span><span
# class="fc8 sc0">287500.0</span><span class="_ _0"> </span><span
# class="fc8 sc0">300000.0</span><span class="_ _0"> </span><span
# class="fc8 sc0">414700.0</span><span class="_ _0"> </span><span
# class="fc8 sc0">450000.0</span><span class="_ _0"> </span><span
# class="fc8 sc0">450000.0</span></span>
#
# <span class="fc8 sc0">NE</span><span class="fc8 sc0">AR </span><span
# class="fc8 sc0">BA</span><span class="_ _1e"></span><span
# class="fc8 sc0">Y</span><span class="_ _0"> </span><span
# class="ff2"><span class="fc8 sc0">2034.0</span><span class="_ _0">
# </span><span class="fc8 sc0">258756.622911</span><span class="_ _0">
# </span><span class="fc8 sc0">122646.084078</span><span class="_ _d">
# </span><span class="fc8 sc0">22500.0</span><span class="_ _0">
# </span><span class="fc8 sc0">162500.0</span><span class="_ _0">
# </span><span class="fc8 sc0">231800.0</span><span class="_ _0">
# </span><span class="fc8 sc0">345525.0</span><span class="_ _0">
# </span><span class="fc8 sc0">500001.0</span></span>
#
# <span class="fc8 sc0">NE</span><span class="fc8 sc0">AR </span><span
# class="fc8 sc0">OCE</span><span class="_ _1f"></span><span
# class="fc8 sc0">AN</span><span class="_ _0"> </span><span
# class="ff2"><span class="fc8 sc0">2372.0</span><span class="_ _0">
# </span><span class="fc8 sc0">249858.342327</span><span class="_ _0">
# </span><span class="fc8 sc0">122701.540906</span><span class="_ _d">
# </span><span class="fc8 sc0">22500.0</span><span class="_ _0">
# </span><span class="fc8 sc0">150000.0</span><span class="_ _0">
# </span><span class="fc8 sc0">229800.0</span><span class="_ _0">
# </span><span class="fc8 sc0">323825.0</span><span class="_ _0">
# </span><span class="fc8 sc0">500001.0</span></span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[12\]:</span>
#
# #Checking unique values in categorical column
#
# df<span class="fc4">\[<span class="fc7">'ocean_proximity'</span>\]<span
# class="ff4 fc6">.</span></span>unique<span class="fc4">()</span>
#
# <span class="fc8 sc0">Out\[12\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[13\]:</span>
#
# #House price based on categorical value.
#
# df<span class="ff4 fc6">.</span>groupby<span class="fc4">(\[<span
# class="fc7">'ocean_proximity'</span>\])\[<span
# class="fc7">'median_house_value'</span>\]<span
# class="ff4 fc6">.</span></span>describe<span class="fc4">()</span>
#
# <span class="fc8 sc0">Out\[13\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[14\]:</span>
#
# #Same information using a bar chart.
#
# df<span class="fc4">\[<span class="fc7">'ocean_proximity'</span>\]<span
# class="ff4 fc6">.</span></span>value_counts<span class="fc4">()<span
# class="ff4 fc6">.</span></span>plot<span class="fc4">(</span>kind<span
# class="ff4 fc6">=</span><span class="fc7">'bar'<span
# class="fc4">)</span></span>
#
# plt<span class="ff4 fc6">.</span>show<span class="fc4">()</span>
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# <span class="fc8 sc0">\<AxesSubplot:xlabel='ocean_proximity',
# </span><span class="fc8 sc0">ylabel='median_house_value'\></span>
#
# <span class="fc8 sc0">\<AxesSubplot:xlabel='median_income', </span><span
# class="fc8 sc0">ylabel='median_house_value'\></span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[15\]:</span>
#
# figure2<span class="fc4">,</span> ax <span class="ff4 fc6">=</span>
# plt<span class="ff4 fc6">.</span>subplots<span
# class="fc4">(</span>figsize <span class="ff4 fc6">=</span> <span
# class="fc4">(<span class="fc9">12</span>,<span
# class="fc9">8</span>))</span>
#
# sns<span class="ff4 fc6">.</span>barplot<span class="fc4">(</span>x
# <span class="ff4 fc6">=</span> <span class="fc7">'ocean_proximity'<span
# class="fc4">,</span></span> y <span class="ff4 fc6">=</span> <span
# class="fc7">'median_house_value'</span> <span class="fc4">,</span> data
# <span class="ff4 fc6">=</span> df<span class="fc4">)</span>
#
# <span class="fc8 sc0">Out\[15\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[16\]:</span>
#
# figure3<span class="fc4">,</span> ax <span class="ff4 fc6">=</span>
# plt<span class="ff4 fc6">.</span>subplots<span
# class="fc4">(</span>figsize <span class="ff4 fc6">=</span> <span
# class="fc4">(<span class="fc9">12</span>,<span
# class="fc9">8</span>))</span>
#
# sns<span class="ff4 fc6">.</span>scatterplot<span class="fc4">(</span>x
# <span class="ff4 fc6">=</span> <span class="fc7">'median_income'<span
# class="fc4">,</span></span> y <span class="ff4 fc6">=</span> <span
# class="fc7">'median_house_value'</span> <span class="fc4">,</span> data
# <span class="ff4 fc6">=</span> df<span class="fc4">)</span>
#
# <span class="fc8 sc0">Out\[16\]:</span>
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# <span class="fc8 sc0">longitude</span><span class="_ _0"> </span><span
# class="fc8 sc0">latitude</span><span class="_ _0"> </span><span
# class="fc8 sc0">housing_median_age</span><span class="_ _0">
# </span><span class="fc8 sc0">households</span><span class="_ _0">
# </span><span class="fc8 sc0">median_income</span><span class="_ _0">
# </span><span class="fc8 sc0">median_house_v</span><span
# class="fc8 sc0">alue</span>
#
# <span class="fc8 sc0">ocean_pr</span><span class="fc8 sc0">o</span><span
# class="fc8 sc0">ximity</span>
#
# <span class="fc8 sc0">O</span>
#
# <span class="fc8 sc0">0</span><span class="_ _1"> </span><span
# class="ff2"><span class="fc8 sc0">-122.23</span><span class="_ _2">
# </span><span class="fc8 sc0">37.88</span><span class="_ _3">
# </span><span class="fc8 sc0">41</span><span class="_ _7"> </span><span
# class="fc8 sc0">126</span><span class="_ _8"> </span><span
# class="fc8 sc0">8.3252</span><span class="_ _20"> </span><span
# class="fc8 sc0">452600</span></span>
#
# <span class="fc8 sc0">1</span><span class="_ _1"> </span><span
# class="ff2"><span class="fc8 sc0">-122.22</span><span class="_ _2">
# </span><span class="fc8 sc0">37.86</span><span class="_ _3">
# </span><span class="fc8 sc0">21</span><span class="_ _b"> </span><span
# class="fc8 sc0">1138</span><span class="_ _8"> </span><span
# class="fc8 sc0">8.3014</span><span class="_ _20"> </span><span
# class="fc8 sc0">358500</span></span>
#
# <span class="fc8 sc0">2</span><span class="_ _1"> </span><span
# class="ff2"><span class="fc8 sc0">-122.25</span><span class="_ _2">
# </span><span class="fc8 sc0">37.85</span><span class="_ _3">
# </span><span class="fc8 sc0">52</span><span class="_ _7"> </span><span
# class="fc8 sc0">259</span><span class="_ _8"> </span><span
# class="fc8 sc0">3.8462</span><span class="_ _20"> </span><span
# class="fc8 sc0">342200</span></span>
#
# <span class="fc8 sc0">3</span><span class="_ _1"> </span><span
# class="ff2"><span class="fc8 sc0">-122.25</span><span class="_ _2">
# </span><span class="fc8 sc0">37.85</span><span class="_ _3">
# </span><span class="fc8 sc0">52</span><span class="_ _7"> </span><span
# class="fc8 sc0">193</span><span class="_ _8"> </span><span
# class="fc8 sc0">4.0368</span><span class="_ _20"> </span><span
# class="fc8 sc0">269700</span></span>
#
# <span class="fc8 sc0">4</span><span class="_ _1"> </span><span
# class="ff2"><span class="fc8 sc0">-122.25</span><span class="_ _2">
# </span><span class="fc8 sc0">37.84</span><span class="_ _3">
# </span><span class="fc8 sc0">52</span><span class="_ _7"> </span><span
# class="fc8 sc0">514</span><span class="_ _8"> </span><span
# class="fc8 sc0">3.6591</span><span class="_ _20"> </span><span
# class="fc8 sc0">299200</span></span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[17\]:</span>
#
# \# Convert categorical variable 'ocean_proximity' into dummy/indicator
# variables
#
# df <span class="ff4 fc6">=</span> pd<span
# class="ff4 fc6">.</span>get_dummies<span class="fc4">(</span>df<span
# class="fc4">,</span> columns<span class="ff4 fc6">=</span><span
# class="fc4">\[<span class="fc7">'ocean_proximity'</span>\])</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[18\]:</span>
#
# #Renaing feature name as it should not contain charaters like \<\>=
# etc...This will give proble<span class="fc8 sc0">m</span>
#
# df<span class="ff4 fc6">.</span>rename<span class="fc4">(</span>columns
# <span class="ff4 fc6">=</span><span class="fc4">{<span
# class="fc7">'ocean_proximity\_\<1H OCEAN'</span></span> <span
# class="fc4">:</span> <span class="fc7">'ocean_proximity_LT1H OCEAN'<span
# class="fc4">},</span></span> inplace <span class="ff4 fc6">=</span>
# <span class="ff4 fc2">Tr</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[19\]:</span>
#
# #Checking for dummies action & feature name change
#
# df<span class="ff4 fc6">.</span>head<span class="fc4">()</span>
#
# <span class="fc8 sc0">Out\[19\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[20\]:</span>
#
# #Distribution of median house value which we are predicting
#
# #Data shows right skewed and some outliers
#
# sns<span class="ff4 fc6">.</span>distplot<span
# class="fc4">(</span>df<span class="fc4">\[<span
# class="fc7">'median_house_value'</span>\])</span>
#
# plt<span class="ff4 fc6">.</span>show<span class="fc4">()</span>
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# <span class="fc8 sc0">\<AxesSubplot:xlabel='median_house_value'\></span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[21\]:</span>
#
# #Confirming via box plot
#
# sns<span class="ff4 fc6">.</span>boxplot<span
# class="fc4">(</span>df<span class="fc4">\[<span
# class="fc7">'median_house_value'</span>\])</span>
#
# <span class="fc8 sc0">Out\[21\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[22\]:</span>
#
# #Trying to identify outliers and remove them
#
# \# IQR
#
# \# Calculate the upper and lower limits
#
# Q1 <span class="ff4 fc6">=</span> df<span class="fc4">\[<span
# class="fc7">'median_house_value'</span>\]<span
# class="ff4 fc6">.</span></span>quantile<span class="fc4">(<span
# class="fc9">0.25</span>)</span>
#
# Q3 <span class="ff4 fc6">=</span> df<span class="fc4">\[<span
# class="fc7">'median_house_value'</span>\]<span
# class="ff4 fc6">.</span></span>quantile<span class="fc4">(<span
# class="fc9">0.75</span>)</span>
#
# IQR <span class="ff4 fc6">=</span> Q3 <span class="ff4 fc6">-</span> Q1
#
# \# Set the threshold for outliers
#
# lower_threshold <span class="ff4 fc6">=</span> Q1 <span
# class="ff4 fc6">-</span> <span class="fc9">1.5</span> <span
# class="ff4 fc6">\*</span> IQR
#
# upper_threshold <span class="ff4 fc6">=</span> Q3 <span
# class="ff4 fc6">+</span> <span class="fc9">1.5</span> <span
# class="ff4 fc6">\*</span> IQR
#
# \# Identify outlier rows using boolean masks
#
# outliers_lower <span class="ff4 fc6">=</span> df<span
# class="fc4">\[<span class="fc7">'median_house_value'</span>\]</span>
# <span class="ff4 fc6">\<</span> lower_threshold
#
# outliers_upper <span class="ff4 fc6">=</span> df<span
# class="fc4">\[<span class="fc7">'median_house_value'</span>\]</span>
# <span class="ff4 fc6">\></span> upper_threshold
#
# \# Display the number of outliers
#
# print<span class="fc4">(<span class="fc7">f"Number of lower outliers:
# {</span></span>outliers_lower<span class="ff4 fc6">.</span>sum<span
# class="fc4">()<span class="fc7">}"</span>)</span>
#
# print<span class="fc4">(<span class="fc7">f"Number of upper outliers:
# {</span></span>outliers_upper<span class="ff4 fc6">.</span>sum<span
# class="fc4">()<span class="fc7">}"</span>)</span>
#
# \# Remove the outliers
#
# df <span class="ff4 fc6">=</span> df<span class="fc4">\[<span
# class="ff4 fc6">\~</span>(</span>outliers_lower <span
# class="ff4 fc6">\|</span> outliers_upper<span class="fc4">)\]<span
# class="ff4 fc6">.</span></span>copy<span class="fc4">()</span>
#
# \# Display the shape of the cleaned DataFrame
#
# print<span class="fc4">(<span class="fc7">f"Shape of the cleaned
# DataFrame: {</span></span>df<span class="ff4 fc6">.</span>shape<span
# class="fc7">}"<span class="fc4">)</span></span>
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# <span class="fc8 sc0">Number </span><span class="fc8 sc0">of
# </span><span class="fc8 sc0">lower </span><span
# class="fc8 sc0">outliers: </span><span class="fc8 sc0">0</span>
#
# <span class="fc8 sc0">Number </span><span class="fc8 sc0">of
# </span><span class="fc8 sc0">upper </span><span
# class="fc8 sc0">outliers: </span><span class="fc8 sc0">957</span>
#
# <span class="fc8 sc0">Shape </span><span class="fc8 sc0">of </span><span
# class="fc8 sc0">the </span><span class="fc8 sc0">cleaned </span><span
# class="fc8 sc0">DataFrame: </span><span class="fc8 sc0">(17419,
# </span><span class="fc8 sc0">11)</span>
#
# <span class="fc8 sc0">\<AxesSubplot:xlabel='median_house_value',
# </span><span class="fc8 sc0">ylabel='Density'\></span>
#
# <span class="fc8 sc0">Index(\[\], </span><span
# class="fc8 sc0">dtype='object')</span>
#
# <span class="fc8 sc0">Index(\['longitude', </span><span
# class="fc8 sc0">'latitude', </span><span
# class="fc8 sc0">'housing_median_age', </span><span
# class="fc8 sc0">'households',</span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">'median_income',
# </span><span class="fc8 sc0">'median_house_value', </span><span
# class="fc8 sc0">'ocean_proximity_LT1H </span><span
# class="fc8 sc0">OCEAN',</span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">'ocean_proximity_INLAND',
# </span><span class="fc8 sc0">'ocean_proximity_ISLAND',</span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0">'ocean_proximity_NEAR
# </span><span class="fc8 sc0">BAY', </span><span
# class="fc8 sc0">'ocean_proximity_NEAR </span><span
# class="fc8 sc0">OCEAN'\],</span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">dtype='object')</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[23\]:</span>
#
# #Confirming outliers removal
#
# sns<span class="ff4 fc6">.</span>distplot<span
# class="fc4">(</span>df<span class="fc4">\[<span
# class="fc7">'median_house_value'</span>\])</span>
#
# plt<span class="ff4 fc6">.</span>show<span class="fc4">()</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[24\]:</span>
#
# sns<span class="ff4 fc6">.</span>distplot<span
# class="fc4">(</span>np<span class="ff4 fc6">.</span>log<span
# class="fc4">(</span>df<span class="fc4">\[<span
# class="fc7">'median_house_value'</span>\]))</span>
#
# <span class="fc8 sc0">Out\[24\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[25\]:</span>
#
# #Checking if any column belongs to object
#
# category_columns <span class="ff4 fc6">=</span> df<span
# class="ff4 fc6">.</span>dtypes<span class="fc4">\[</span>df<span
# class="ff4 fc6">.</span>dtypes<span class="ff4 fc6">==</span><span
# class="fc7">'object'<span class="fc4">\]<span
# class="ff4 fc6">.</span></span></span>index
#
# numerical_columns <span class="ff4 fc6">=</span> df<span
# class="ff4 fc6">.</span>dtypes<span class="fc4">\[</span>df<span
# class="ff4 fc6">.</span>dtypes<span class="ff4 fc6">!=</span><span
# class="fc7">'object'<span class="fc4">\]<span
# class="ff4 fc6">.</span></span></span>index
#
# print<span class="fc4">(</span>category_columns<span
# class="fc4">)</span>
#
# print<span class="fc4">(</span>numerical_columns<span
# class="fc4">)</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[26\]:</span>
#
# #Seperating input features and labels
#
# X <span class="ff4 fc6">=</span> df<span
# class="ff4 fc6">.</span>drop<span class="fc4">(<span
# class="fc7">'median_house_value'</span>,</span> axis <span
# class="ff4 fc6">=</span> <span class="fc9">1<span
# class="fc4">)</span></span>
#
# Y <span class="ff4 fc6">=</span> np<span
# class="ff4 fc6">.</span>log<span class="fc4">(</span>df<span
# class="fc4">\[<span class="fc7">'median_house_value'</span>\])</span>
#
# print<span class="fc4">(</span>type<span class="fc4">(</span>X<span
# class="fc4">))</span>
#
# print<span class="fc4">(</span>type<span class="fc4">(</span>Y<span
# class="fc4">))</span>
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# <span class="fc8 sc0">\<class </span><span
# class="fc8 sc0">'pandas.core.frame.DataFrame'\></span>
#
# <span class="fc8 sc0">\<class </span><span
# class="fc8 sc0">'pandas.core.series.Series'\></span>
#
# <span class="fc8 sc0">(17419, </span><span class="fc8 sc0">10)</span>
#
# <span class="fc8 sc0">(17419,)</span>
#
# <span class="fc8 sc0">(13935, </span><span class="fc8 sc0">10)</span>
#
# <span class="fc8 sc0">(3484, </span><span class="fc8 sc0">10)</span>
#
# <span class="fc8 sc0">(13935,)</span>
#
# <span class="fc8 sc0">(3484,)</span>
#
# <span class="fc8 sc0">longitude</span><span class="_ _0"> </span><span
# class="fc8 sc0">latitude</span><span class="_ _0"> </span><span
# class="fc8 sc0">housing_median_age</span><span class="_ _0">
# </span><span class="fc8 sc0">households</span><span class="_ _0">
# </span><span class="fc8 sc0">median_income</span><span class="_ _0">
# </span><span class="fc8 sc0">median_house_v</span><span
# class="fc8 sc0">alue</span>
#
# <span class="fc8 sc0">ocean_pr</span><span class="fc8 sc0">o</span><span
# class="fc8 sc0">ximity</span>
#
# <span class="fc8 sc0">O</span>
#
# <span class="fc8 sc0">0</span><span class="_ _1"> </span><span
# class="ff2"><span class="fc8 sc0">-122.23</span><span class="_ _2">
# </span><span class="fc8 sc0">37.88</span><span class="_ _3">
# </span><span class="fc8 sc0">41</span><span class="_ _7"> </span><span
# class="fc8 sc0">126</span><span class="_ _8"> </span><span
# class="fc8 sc0">8.3252</span><span class="_ _20"> </span><span
# class="fc8 sc0">452600</span></span>
#
# <span class="fc8 sc0">1</span><span class="_ _1"> </span><span
# class="ff2"><span class="fc8 sc0">-122.22</span><span class="_ _2">
# </span><span class="fc8 sc0">37.86</span><span class="_ _3">
# </span><span class="fc8 sc0">21</span><span class="_ _b"> </span><span
# class="fc8 sc0">1138</span><span class="_ _8"> </span><span
# class="fc8 sc0">8.3014</span><span class="_ _20"> </span><span
# class="fc8 sc0">358500</span></span>
#
# <span class="fc8 sc0">2</span><span class="_ _1"> </span><span
# class="ff2"><span class="fc8 sc0">-122.25</span><span class="_ _2">
# </span><span class="fc8 sc0">37.85</span><span class="_ _3">
# </span><span class="fc8 sc0">52</span><span class="_ _7"> </span><span
# class="fc8 sc0">259</span><span class="_ _8"> </span><span
# class="fc8 sc0">3.8462</span><span class="_ _20"> </span><span
# class="fc8 sc0">342200</span></span>
#
# <span class="fc8 sc0">3</span><span class="_ _1"> </span><span
# class="ff2"><span class="fc8 sc0">-122.25</span><span class="_ _2">
# </span><span class="fc8 sc0">37.85</span><span class="_ _3">
# </span><span class="fc8 sc0">52</span><span class="_ _7"> </span><span
# class="fc8 sc0">193</span><span class="_ _8"> </span><span
# class="fc8 sc0">4.0368</span><span class="_ _20"> </span><span
# class="fc8 sc0">269700</span></span>
#
# <span class="fc8 sc0">4</span><span class="_ _1"> </span><span
# class="ff2"><span class="fc8 sc0">-122.25</span><span class="_ _2">
# </span><span class="fc8 sc0">37.84</span><span class="_ _3">
# </span><span class="fc8 sc0">52</span><span class="_ _7"> </span><span
# class="fc8 sc0">514</span><span class="_ _8"> </span><span
# class="fc8 sc0">3.6591</span><span class="_ _20"> </span><span
# class="fc8 sc0">299200</span></span>
#
# print<span class="fc4">(</span>X<span class="ff4 fc6">.</span>shape<span
# class="fc4">)</span>
#
# print<span class="fc4">(</span>Y<span class="ff4 fc6">.</span>shape<span
# class="fc4">)</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[27\]:</span>
#
# \# Split the dataset into training and testing sets
#
# x_train<span class="fc4">,</span> x_test<span class="fc4">,</span>
# y_train<span class="fc4">,</span> y_test <span class="ff4 fc6">=</span>
# train_test_split<span class="fc4">(</span>X<span class="fc4">,</span>
# Y<span class="fc4">,</span> test_size<span class="ff4 fc6">=</span><span
# class="fc9">0.2<span class="fc4">,</span></span> random_state<span
# class="ff4 fc6">=</span><span class="fc9">42<span
# class="fc4">)</span></span>
#
# print<span class="fc4">(</span>x_train<span
# class="ff4 fc6">.</span>shape<span class="fc4">)</span>
#
# print<span class="fc4">(</span>x_test<span
# class="ff4 fc6">.</span>shape<span class="fc4">)</span>
#
# print<span class="fc4">(</span>y_train<span
# class="ff4 fc6">.</span>shape<span class="fc4">)</span>
#
# print<span class="fc4">(</span>y_test<span
# class="ff4 fc6">.</span>shape<span class="fc4">)</span>
#
# df<span class="ff4 fc6">.</span>head<span class="fc4">()</span>
#
# <span class="fc8 sc0">Out\[27\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[28\]:</span>
#
# \# \# Standardize the features using StandardScaler
#
# \# scaler = StandardScaler()
#
# \# X_train = scaler.fit_transform(x_train)
#
# \# X_test = scaler.transform(x_test)
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[29\]:</span>
#
# #Defining functions to calculate R2 and error rate
#
# def<span class="ff3 fc3"> model_evaluation<span
# class="fc4">(</span>y_test<span class="fc4">,</span> y_pred<span
# class="fc4">):</span></span>
#
# mae <span class="ff4 fc6">=</span> mean_absolute_error<span
# class="fc4">(</span>y_test<span class="fc4">,</span> y_pred<span
# class="fc4">)</span>
#
# mse <span class="ff4 fc6">=</span> mean_squared_error<span
# class="fc4">(</span>y_test<span class="fc4">,</span> y_pred<span
# class="fc4">)</span>
#
# rmse <span class="ff4 fc6">=</span> mean_squared_error<span
# class="fc4">(</span>y_test<span class="fc4">,</span> y_pred<span
# class="fc4">,</span> squared<span class="ff4 fc6">=<span
# class="fc2">False</span></span><span class="fc4">)</span>
#
# <span class="ff5 fc5">\# r2_scr = r2_score(y_test, y_pred)</span>
#
# <span class="ff4 fc2">return</span> <span class="fc4">{<span
# class="fc7">'mae'</span>:</span> mae<span class="fc4">,</span> <span
# class="fc7">'mse'<span class="fc4">:</span></span> mse<span
# class="fc4">,</span> <span class="fc7">'rmse'<span
# class="fc4">:</span></span> rmse<span class="fc4">}</span>
#
# def<span class="ff3 fc3"> model_instantiation<span
# class="fc4">(</span>model<span class="fc4">,</span> x_train<span
# class="fc4">,</span> x_test<span class="fc4">,</span> y_train<span
# class="fc4">,</span> y_test<span class="fc4">,</span> y_pred<span
# class="fc4">,</span> model_name<span class="fc4">):</span></span>
#
# training_r2 <span class="ff4 fc6">=</span> model<span
# class="ff4 fc6">.</span>score<span class="fc4">(</span>x_train<span
# class="fc4">,</span> y_train<span class="fc4">)</span>
#
# testing_r2 <span class="ff4 fc6">=</span> model<span
# class="ff4 fc6">.</span>score<span class="fc4">(</span>x_test<span
# class="fc4">,</span> y_test<span class="fc4">)</span>
#
# eval_return <span class="ff4 fc6">=</span> model_evaluation<span
# class="fc4">(</span>y_test<span class="fc4">,</span> y_pred<span
# class="fc4">)</span>
#
# result_metric <span class="ff4 fc6">=</span> <span class="fc4">{</span>
#
# <span class="fc7">'Train_R2'<span class="fc4">:</span></span>
# training_r2<span class="fc4">,</span>
#
# <span class="fc7">'Test_R2'<span class="fc4">:</span></span>
# testing_r2<span class="fc4">,</span>
#
# <span class="fc7">'Test_MSE'<span class="fc4">:</span></span>
# eval_return<span class="fc4">\[<span class="fc7">'mse'</span>\],</span>
#
# <span class="fc7">'Test_RMSE'<span class="fc4">:</span></span>
# eval_return<span class="fc4">\[<span class="fc7">'rmse'</span>\],</span>
#
# <span class="fc7">'Test_MAE'<span class="fc4">:</span></span>
# eval_return<span class="fc4">\[<span class="fc7">'mae'</span>\]</span>
#
# <span class="fc4">}</span>
#
# result <span class="ff4 fc6">=</span> pd<span
# class="ff4 fc6">.</span>DataFrame<span
# class="fc4">(</span>result_metric<span class="fc4">,</span> index<span
# class="ff4 fc6">=</span><span class="fc4">\[</span>model_name<span
# class="fc4">\])</span>
#
# <span class="ff4 fc2">return</span> result
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[30\]:</span>
#
# from<span class="ff3 fc3"> sklearn.linear_model </span>import<span
# class="ff3 fc3"> LinearRegression</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[31\]:</span>
#
# #Instantiating Linear reg model
#
# linear_reg <span class="ff4 fc6">=</span> LinearRegression<span
# class="fc4">()</span>
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# <span class="fc8 sc0">T</span><span class="_ _1e"></span><span
# class="fc8 sc0">rain_R2</span><span class="_ _21"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_R2</span><span class="_ _0"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_MSE</span><span class="_ _0"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_RMSE</span><span class="_ _0"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_MAE</span>
#
# <span class="fc8 sc0">Linear </span><span class="fc8 sc0">R</span><span
# class="fc8 sc0">egr</span><span class="_ _23"></span><span
# class="fc8 sc0">ession</span><span class="_ _0"> </span><span
# class="ff2"><span class="fc8 sc0">0.630962</span><span class="_ _0">
# </span><span class="fc8 sc0">0.624499</span><span class="_ _24">
# </span><span class="fc8 sc0">0.10712</span><span class="_ _25">
# </span><span class="fc8 sc0">0.327293</span><span class="_ _21">
# </span><span class="fc8 sc0">0.251028</span></span>
#
# <span class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">rain_R2</span><span class="_ _26"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_R2</span><span class="_ _0"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_MSE</span><span class="_ _0"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_RMSE</span><span class="_ _0"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_MAE</span>
#
# <span class="fc8 sc0">D</span><span class="_ _1e"></span><span
# class="fc8 sc0">T</span><span class="_ _1e"></span><span
# class="fc8 sc0">r</span><span class="fc8 sc0">ee_R</span><span
# class="fc8 sc0">egr</span><span class="fc8 sc0">ession</span><span
# class="_ _0"> </span><span class="ff2"><span
# class="fc8 sc0">0.763267</span><span class="_ _0"> </span><span
# class="fc8 sc0">0.717443</span><span class="_ _27"> </span><span
# class="fc8 sc0">0.080606</span><span class="_ _25"> </span><span
# class="fc8 sc0">0.283912</span><span class="_ _21"> </span><span
# class="fc8 sc0">0.208418</span></span>
#
# <span class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">rain_R2</span><span class="_ _26"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_R2</span><span class="_ _0"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_MSE</span><span class="_ _0"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_RMSE</span><span class="_ _0"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_MAE</span>
#
# <span class="fc8 sc0">RF_R</span><span class="fc8 sc0">egr</span><span
# class="_ _23"></span><span class="fc8 sc0">ession</span><span
# class="_ _0"> </span><span class="ff2"><span
# class="fc8 sc0">0.850595</span><span class="_ _0"> </span><span
# class="fc8 sc0">0.774959</span><span class="_ _27"> </span><span
# class="fc8 sc0">0.064198</span><span class="_ _25"> </span><span
# class="fc8 sc0">0.253374</span><span class="_ _26"> </span><span
# class="fc8 sc0">0.180186</span></span>
#
# linear_reg<span class="ff4 fc6">.</span>fit<span
# class="fc4">(</span>x_train<span class="fc4">,</span> y_train<span
# class="fc4">)</span>
#
# <span class="fc8 sc0">Out\[31\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[32\]:</span>
#
# #Predicting via LR
#
# y_pred_LR <span class="ff4 fc6">=</span> linear_reg<span
# class="ff4 fc6">.</span>predict<span class="fc4">(</span>x_test<span
# class="fc4">)</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[33\]:</span>
#
# LR_df <span class="ff4 fc6">=</span> model_instantiation<span
# class="fc4">(</span>linear_reg <span class="fc4">,</span>x_train<span
# class="fc4">,</span>x_test<span class="fc4">,</span>y_train<span
# class="fc4">,</span>y_test<span class="fc4">,</span>y_pred_LR <span
# class="fc4">,</span> <span class="fc7">'Linear Reg</span>
#
# LR_df
#
# <span class="fc8 sc0">Out\[33\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[34\]:</span>
#
# from<span class="ff3 fc3"> sklearn.tree </span>import<span
# class="ff3 fc3"> DecisionTreeRegressor</span>
#
# from<span class="ff3 fc3"> sklearn.ensemble </span>import<span
# class="ff3 fc3"> RandomForestRegressor<span class="fc4">,</span>
# AdaBoostRegressor</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[35\]:</span>
#
# #Decision Tree
#
# Decs_Tree <span class="ff4 fc6">=</span> DecisionTreeRegressor<span
# class="fc4">(</span>max_depth <span class="ff4 fc6">=</span> <span
# class="fc9">8</span> <span class="fc4">,</span> min_samples_leaf <span
# class="ff4 fc6">=</span><span class="fc9">10</span> <span
# class="fc4">,</span> min_samples_split <span class="ff4 fc6">=</span>
#
# Decs_Tree<span class="ff4 fc6">.</span>fit<span
# class="fc4">(</span>x_train<span class="fc4">,</span> y_train<span
# class="fc4">)</span>
#
# <span class="fc8 sc0">Out\[35\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[36\]:</span>
#
# y_pred_DT <span class="ff4 fc6">=</span> Decs_Tree<span
# class="ff4 fc6">.</span>predict<span class="fc4">(</span>x_test<span
# class="fc4">)</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[37\]:</span>
#
# DT_df <span class="ff4 fc6">=</span> model_instantiation<span
# class="fc4">(</span>Decs_Tree <span class="fc4">,</span>x_train<span
# class="fc4">,</span>x_test<span class="fc4">,</span>y_train<span
# class="fc4">,</span>y_test<span class="fc4">,</span>y_pred_DT <span
# class="fc4">,</span> <span class="fc7">'DTree_Regre</span>
#
# DT_df
#
# <span class="fc8 sc0">Out\[37\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[38\]:</span>
#
# #Randon forest
#
# Rand_Forest <span class="ff4 fc6">=</span> RandomForestRegressor<span
# class="fc4">(</span>n_estimators<span class="ff4 fc6">=</span><span
# class="fc9">300<span class="fc4">,</span></span> max_depth <span
# class="ff4 fc6">=</span> <span class="fc9">10<span
# class="fc4">,</span></span> min_samples_split<span
# class="ff4 fc6">=</span><span class="fc9">12<span
# class="fc4">)</span></span>
#
# Rand_Forest<span class="ff4 fc6">.</span>fit<span
# class="fc4">(</span>x_train<span class="fc4">,</span> y_train<span
# class="fc4">)</span>
#
# <span class="fc8 sc0">Out\[38\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[39\]:</span>
#
# y_pred_RF <span class="ff4 fc6">=</span> Rand_Forest<span
# class="ff4 fc6">.</span>predict<span class="fc4">(</span>x_test<span
# class="fc4">)</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[40\]:</span>
#
# RF_df <span class="ff4 fc6">=</span> model_instantiation<span
# class="fc4">(</span>Rand_Forest <span class="fc4">,</span>x_train<span
# class="fc4">,</span>x_test<span class="fc4">,</span>y_train<span
# class="fc4">,</span>y_test<span class="fc4">,</span>y_pred_RF <span
# class="fc4">,</span> <span class="fc7">'RF_Regres</span>
#
# RF_df
#
# <span class="fc8 sc0">Out\[40\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[41\]:</span>
#
# Rand_Forest_2 <span class="ff4 fc6">=</span> RandomForestRegressor<span
# class="fc4">(</span>n_estimators<span class="ff4 fc6">=</span><span
# class="fc9">300<span class="fc4">,</span></span> max_depth <span
# class="ff4 fc6">=</span> <span class="fc9">9<span
# class="fc4">,</span></span> min_samples_split<span
# class="ff4 fc6">=</span><span class="fc9">4<span
# class="fc4">)</span></span>
#
# Rand_Forest_2<span class="ff4 fc6">.</span>fit<span
# class="fc4">(</span>x_train<span class="fc4">,</span> y_train<span
# class="fc4">)</span>
#
# y_pred_RF_2 <span class="ff4 fc6">=</span> Rand_Forest_2<span
# class="ff4 fc6">.</span>predict<span class="fc4">(</span>x_test<span
# class="fc4">)</span>
#
# ▾<span class="_ _28"> </span><span class="fc0">LinearRegression</span>
#
# LinearRegression()
#
# ▾<span class="_ _29"> </span><span
# class="fc0">DecisionTreeRegressor</span>
#
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=10,
# min_samples_split=10)
#
# ▾<span class="_ _2a"> </span><span
# class="fc0">RandomForestRegressor</span>
#
# RandomForestRegressor(max_depth=10, min_samples_split=12,
# n_estimators=300)
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# <span class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">rain_R2</span><span class="_ _26"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_R2</span><span class="_ _0"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_MSE</span><span class="_ _0"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_RMSE</span><span class="_ _0"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_MAE</span>
#
# <span class="fc8 sc0">RF2_R</span><span class="fc8 sc0">egr</span><span
# class="_ _23"></span><span class="fc8 sc0">ession</span><span
# class="_ _0"> </span><span class="ff2"><span
# class="fc8 sc0">0.830124</span><span class="_ _0"> </span><span
# class="fc8 sc0">0.763076</span><span class="_ _27"> </span><span
# class="fc8 sc0">0.067588</span><span class="_ _25"> </span><span
# class="fc8 sc0">0.259977</span><span class="_ _26"> </span><span
# class="fc8 sc0">0.186851</span></span>
#
# <span class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">rain_R2</span><span class="_ _26"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_R2</span><span class="_ _0"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_MSE</span><span class="_ _0"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_RMSE</span><span class="_ _0"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_MAE</span>
#
# <span class="fc8 sc0">AD</span><span class="fc8 sc0">A_R</span><span
# class="_ _1e"></span><span class="fc8 sc0">egr</span><span
# class="fc8 sc0">ession</span><span class="_ _0"> </span><span
# class="ff2"><span class="fc8 sc0">0.599874</span><span class="_ _0">
# </span><span class="fc8 sc0">0.586475</span><span class="_ _2b">
# </span><span class="fc8 sc0">0.117968</span><span class="_ _25">
# </span><span class="fc8 sc0">0.343464</span><span class="_ _21">
# </span><span class="fc8 sc0">0.271343</span></span>
#
# <span class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">rain_R2</span><span class="_ _26"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_R2</span><span class="_ _0"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_MSE</span><span class="_ _0"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_RMSE</span><span class="_ _0"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_MAE</span>
#
# <span class="fc8 sc0">X</span><span class="fc8 sc0">GB_R</span><span
# class="_ _1e"></span><span class="fc8 sc0">egr</span><span
# class="fc8 sc0">ession</span><span class="_ _0"> </span><span
# class="ff2"><span class="fc8 sc0">0.923149</span><span class="_ _0">
# </span><span class="fc8 sc0">0.801669</span><span class="_ _2b">
# </span><span class="fc8 sc0">0.056579</span><span class="_ _25">
# </span><span class="fc8 sc0">0.237862</span><span class="_ _21">
# </span><span class="fc8 sc0">0.163638</span></span>
#
# RF_df_2 <span class="ff4 fc6">=</span> model_instantiation<span
# class="fc4">(</span>Rand_Forest_2 <span class="fc4">,</span>x_train<span
# class="fc4">,</span>x_test<span class="fc4">,</span>y_train<span
# class="fc4">,</span>y_test<span class="fc4">,</span>y_pred_RF_2 <span
# class="fc4">,</span> <span class="fc7">'RF2</span>
#
# RF_df_2
#
# <span class="fc8 sc0">Out\[41\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[42\]:</span>
#
# ada <span class="ff4 fc6">=</span>AdaBoostRegressor<span
# class="fc4">(</span>n_estimators <span class="ff4 fc6">=</span> <span
# class="fc9">300<span class="fc4">,</span></span> random_state <span
# class="ff4 fc6">=</span> <span class="fc9">10<span
# class="fc4">)</span></span>
#
# ada<span class="ff4 fc6">.</span>fit<span
# class="fc4">(</span>x_train<span class="fc4">,</span>y_train<span
# class="fc4">)</span>
#
# y_pred_ada <span class="ff4 fc6">=</span> ada<span
# class="ff4 fc6">.</span>predict<span class="fc4">(</span>x_test<span
# class="fc4">)</span>
#
# ada_df <span class="ff4 fc6">=</span> model_instantiation<span
# class="fc4">(</span>ada <span class="fc4">,</span>x_train<span
# class="fc4">,</span>x_test<span class="fc4">,</span>y_train<span
# class="fc4">,</span>y_test<span class="fc4">,</span>y_pred_ada <span
# class="fc4">,</span> <span class="fc7">'ADA_Regression'</span>
#
# ada_df
#
# <span class="fc8 sc0">Out\[42\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[43\]:</span>
#
# from<span class="ff3 fc3"> xgboost.sklearn </span>import<span
# class="ff3 fc3"> XGBRegressor</span>
#
# xgb_model <span class="ff4 fc6">=</span> XGBRegressor<span
# class="fc4">()</span>
#
# \# Define the parameter grid to search
#
# \# param_grid = {
#
# \# 'n_estimators': \[100, 200, 300\],
#
# \# 'learning_rate': \[0.01, 0.1, 0.2\],
#
# \# 'max_depth': \[3, 4, 5\],
#
# \# 'subsample': \[0.8, 0.9, 1.0\],
#
# \# 'colsample_bytree': \[0.8, 0.9, 1.0\],
#
# \# 'reg_alpha': \[0, 0.1, 0.5\], \# Regularization term on weights (L1)
#
# \# 'reg_lambda': \[0, 0.1, 0.5\] \# Regularization term on weights (L2)
#
# \# }
#
# \# \# \# Create GridSearchCV
#
# \# grid_search = GridSearchCV(estimator=xgb_model,
# param_grid=param_grid, scoring='neg_mean_sq
#
# \#
# grid_search.fit(x_train,y_train,early_stopping_rounds=10,eval_set=\[(x_test,
# y_test)\], verbo
#
# \# XGB_Best_Model = grid_search.best_estimator\_
#
# \# y_pred_xgboost = XGB_Best_Model.predict(x_test)
#
# xgb_model<span class="ff4 fc6">.</span>fit<span
# class="fc4">(</span>x_train<span class="fc4">,</span>y_train<span
# class="fc4">)</span>
#
# y_pred_xgboost <span class="ff4 fc6">=</span> xgb_model<span
# class="ff4 fc6">.</span>predict<span class="fc4">(</span>x_test<span
# class="fc4">)</span>
#
# xgboost_df <span class="ff4 fc6">=</span> model_instantiation<span
# class="fc4">(</span>xgb_model<span class="fc4">,</span> x_train<span
# class="fc4">,</span> x_test<span class="fc4">,</span> y_train<span
# class="fc4">,</span> y_test<span class="fc4">,</span>
# y_pred_xgboost<span class="fc4">,</span>
#
# xgboost_df
#
# <span class="fc8 sc0">Out\[43\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[ </span><span
# class="fc8 sc0">\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[44\]:</span>
#
# import<span class="ff3 fc3"> tensorflow </span>as<span class="ff3 fc3">
# tf</span>
#
# from<span class="ff3 fc3"> tensorflow.keras.models </span>import<span
# class="ff3 fc3"> Sequential</span>
#
# from<span class="ff3 fc3"> tensorflow.keras.layers </span>import<span
# class="ff3 fc3"> Dense<span class="fc4">,</span> Dropout<span
# class="fc4">,</span> BatchNormalization</span>
#
# from<span class="ff3 fc3"> tensorflow.keras.callbacks </span>import<span
# class="ff3 fc3"> EarlyStopping</span>
#
# from<span class="ff3 fc3"> sklearn.pipeline </span>import<span
# class="ff3 fc3"> make_pipeline</span>
#
# from<span class="ff3 fc3"> tensorflow.keras.regularizers
# </span>import<span class="ff3 fc3"> l2</span>
#
# \# \# Separate features (X) and target variable (y)
#
# X <span class="ff4 fc6">=</span> df<span
# class="ff4 fc6">.</span>drop<span class="fc4">(<span
# class="fc7">'median_house_value'</span>,</span> axis<span
# class="ff4 fc6">=</span><span class="fc9">1<span
# class="fc4">)</span></span>
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# y <span class="ff4 fc6">=</span> df<span class="fc4">\[<span
# class="fc7">'median_house_value'</span>\]</span>
#
# \# \# Split the data into training and testing sets
#
# X_train<span class="fc4">,</span> X_test<span class="fc4">,</span>
# y_train<span class="fc4">,</span> y_test <span class="ff4 fc6">=</span>
# train_test_split<span class="fc4">(</span>X<span class="fc4">,</span>
# y<span class="fc4">,</span> test_size<span class="ff4 fc6">=</span><span
# class="fc9">0.2<span class="fc4">,</span></span> random_state<span
# class="ff4 fc6">=</span><span class="fc9">42<span
# class="fc4">)</span></span>
#
# \# \# Create a pipeline with StandardScaler and PolynomialFeatures
#
# pipeline <span class="ff4 fc6">=</span> make_pipeline<span
# class="fc4">(</span>StandardScaler<span class="fc4">(),</span>
# PolynomialFeatures<span class="fc4">(</span>degree<span
# class="ff4 fc6">=</span><span class="fc9">2<span
# class="fc4">,</span></span> include_bias<span class="ff4 fc6">=<span
# class="fc2">False</span></span><span class="fc4">))</span>
#
# \# \# Fit and transform the training data
#
# X_train_poly <span class="ff4 fc6">=</span> pipeline<span
# class="ff4 fc6">.</span>fit_transform<span
# class="fc4">(</span>X_train<span class="fc4">)</span>
#
# \# \# Transform the testing data
#
# X_test_poly <span class="ff4 fc6">=</span> pipeline<span
# class="ff4 fc6">.</span>transform<span class="fc4">(</span>X_test<span
# class="fc4">)</span>
#
# \# Build a multi-layer neural network model
#
# model <span class="ff4 fc6">=</span> Sequential<span
# class="fc4">()</span>
#
# model<span class="ff4 fc6">.</span>add<span
# class="fc4">(</span>Dense<span class="fc4">(<span
# class="fc9">128</span>,</span> input_dim<span
# class="ff4 fc6">=</span>X_train_poly<span
# class="ff4 fc6">.</span>shape<span class="fc4">\[<span
# class="fc9">1</span>\],</span> activation<span
# class="ff4 fc6">=</span><span class="fc7">'relu'<span
# class="fc4">,</span></span> kernel_regularizer<span
# class="ff4 fc6">=</span>l
#
# model<span class="ff4 fc6">.</span>add<span
# class="fc4">(</span>Dropout<span class="fc4">(<span
# class="fc9">0.2</span>))</span>
#
# model<span class="ff4 fc6">.</span>add<span
# class="fc4">(</span>Dense<span class="fc4">(<span
# class="fc9">64</span>,</span> activation<span
# class="ff4 fc6">=</span><span class="fc7">'relu'<span
# class="fc4">,</span></span> kernel_regularizer<span
# class="ff4 fc6">=</span>l2<span class="fc4">(<span
# class="fc9">0.001</span>)))</span>
#
# model<span class="ff4 fc6">.</span>add<span
# class="fc4">(</span>BatchNormalization<span class="fc4">())</span>
#
# model<span class="ff4 fc6">.</span>add<span
# class="fc4">(</span>Dense<span class="fc4">(<span
# class="fc9">32</span>,</span> activation<span
# class="ff4 fc6">=</span><span class="fc7">'relu'<span
# class="fc4">,</span></span> kernel_regularizer<span
# class="ff4 fc6">=</span>l2<span class="fc4">(<span
# class="fc9">0.001</span>)))</span>
#
# model<span class="ff4 fc6">.</span>add<span
# class="fc4">(</span>Dense<span class="fc4">(<span
# class="fc9">16</span>,</span> activation<span
# class="ff4 fc6">=</span><span class="fc7">'relu'<span
# class="fc4">,</span></span> kernel_regularizer<span
# class="ff4 fc6">=</span>l2<span class="fc4">(<span
# class="fc9">0.001</span>)))</span>
#
# model<span class="ff4 fc6">.</span>add<span
# class="fc4">(</span>Dense<span class="fc4">(<span
# class="fc9">1</span>,</span> activation<span
# class="ff4 fc6">=</span><span class="fc7">'relu'<span
# class="fc4">))</span></span>
#
# \# Define early stopping callback
#
# early_stopping <span class="ff4 fc6">=</span> EarlyStopping<span
# class="fc4">(</span>monitor<span class="ff4 fc6">=</span><span
# class="fc7">'val_loss'<span class="fc4">,</span></span> patience<span
# class="ff4 fc6">=</span><span class="fc9">10<span
# class="fc4">,</span></span> restore_best_weights<span
# class="ff4 fc6">=<span class="fc2">True</span></span><span
# class="fc4">)</span>
#
# \# Compile the model with an adjusted learning rate
#
# optimizer <span class="ff4 fc6">=</span> tf<span
# class="ff4 fc6">.</span>keras<span
# class="ff4 fc6">.</span>optimizers<span
# class="ff4 fc6">.</span>Adam<span class="fc4">(</span>learning_rate<span
# class="ff4 fc6">=</span><span class="fc9">0.0001<span
# class="fc4">)</span></span>
#
# model<span class="ff4 fc6">.</span>compile<span
# class="fc4">(</span>optimizer<span
# class="ff4 fc6">=</span>optimizer<span class="fc4">,</span> loss<span
# class="ff4 fc6">=</span><span class="fc7">'mean_squared_error'<span
# class="fc4">)</span></span>
#
# \# Train the model
#
# model<span class="ff4 fc6">.</span>fit<span
# class="fc4">(</span>X_train_poly<span class="fc4">,</span> y_train<span
# class="fc4">,</span> epochs<span class="ff4 fc6">=</span><span
# class="fc9">50<span class="fc4">,</span></span> batch_size<span
# class="ff4 fc6">=</span><span class="fc9">32<span
# class="fc4">,</span></span> validation_split<span
# class="ff4 fc6">=</span><span class="fc9">0.2<span
# class="fc4">,</span></span> callbacks<span class="ff4 fc6">=</span><span
# class="fc4">\[</span>e
#
# \# Make predictions on the test set
#
# predictions <span class="ff4 fc6">=</span> model<span
# class="ff4 fc6">.</span>predict<span
# class="fc4">(</span>X_test_poly<span class="fc4">)</span>
#
# \# Evaluate the model
#
# mse <span class="ff4 fc6">=</span> mean_squared_error<span
# class="fc4">(</span>y_test<span class="fc4">,</span> predictions<span
# class="fc4">)</span>
#
# r2 <span class="ff4 fc6">=</span> r2_score<span
# class="fc4">(</span>y_test<span class="fc4">,</span> predictions<span
# class="fc4">)</span>
#
# print<span class="fc4">(<span class="fc7">f'Mean Squared Error:
# {</span></span>mse<span class="fc7">}'<span class="fc4">)</span></span>
#
# print<span class="fc4">(<span class="fc7">f'R-squared:
# {</span></span>r2<span class="fc7">}'<span class="fc4">)</span></span>
#
# \# xgboost_df = model_instantiation(model, x_train, x_test, y_train,
# y_test, predictions, 'Ten
#
# \# xgboost_df
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">1/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">3s </span><span
# class="fc8 sc0">4ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">45521571840.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">4</span>
#
# <span class="fc8 sc0">5659099136.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">2/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">4ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">45513981952.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">4</span>
#
# <span class="fc8 sc0">5651877888.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">3/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">45483630592.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">4</span>
#
# <span class="fc8 sc0">5618933760.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">4/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">45420085248.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">4</span>
#
# <span class="fc8 sc0">5588664320.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">5/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">45316804608.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">4</span>
#
# <span class="fc8 sc0">5505753088.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">6/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">45167734784.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">4</span>
#
# <span class="fc8 sc0">5382037504.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">7/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">44966608896.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">4</span>
#
# <span class="fc8 sc0">5313585152.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">8/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">44703805440.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">4</span>
#
# <span class="fc8 sc0">5178540032.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">9/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">44380065792.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">4</span>
#
# <span class="fc8 sc0">5011771392.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">10/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">43981303808.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">4</span>
#
# <span class="fc8 sc0">4739723264.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">11/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">43510579200.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">4</span>
#
# <span class="fc8 sc0">4404719616.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">12/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">2ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">42954420224.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">4</span>
#
# <span class="fc8 sc0">4059979776.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">13/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">42316414976.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">4</span>
#
# <span class="fc8 sc0">3515187200.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">14/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">41571135488.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">4</span>
#
# <span class="fc8 sc0">3261763584.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">15/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">40685912064.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">4</span>
#
# <span class="fc8 sc0">2615050240.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">16/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">39722323968.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">4</span>
#
# <span class="fc8 sc0">1998520320.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">17/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">38568656896.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">4</span>
#
# <span class="fc8 sc0">1106513920.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">18/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">37363703808.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">4</span>
#
# <span class="fc8 sc0">0114827264.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">19/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">4ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">36029636608.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">3</span>
#
# <span class="fc8 sc0">9349116928.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">20/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">34568691712.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">3</span>
#
# <span class="fc8 sc0">8629601280.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">21/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">33029892096.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">3</span>
#
# <span class="fc8 sc0">8276018176.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">22/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">31390441472.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">3</span>
#
# <span class="fc8 sc0">6098195456.0000</span>
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">23/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">29657585664.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">3</span>
#
# <span class="fc8 sc0">5949268992.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">24/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">27854807040.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">3</span>
#
# <span class="fc8 sc0">4343340032.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">25/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">26037495808.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">3</span>
#
# <span class="fc8 sc0">2776638464.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">26/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">24125790208.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">3</span>
#
# <span class="fc8 sc0">1230275584.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">27/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">22231838720.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">3</span>
#
# <span class="fc8 sc0">0732843008.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">28/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">2ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">20321949696.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">2</span>
#
# <span class="fc8 sc0">8998916096.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">29/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">18474164224.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">2</span>
#
# <span class="fc8 sc0">7636432896.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">30/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">4ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">16617832448.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">2</span>
#
# <span class="fc8 sc0">5972879360.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">31/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">15004934144.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">2</span>
#
# <span class="fc8 sc0">5463404544.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">32/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">4ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">13281187840.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">2</span>
#
# <span class="fc8 sc0">4184819712.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">33/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">12014547968.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">2</span>
#
# <span class="fc8 sc0">1572216832.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">34/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">10627654656.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">2</span>
#
# <span class="fc8 sc0">2135050240.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">35/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">9489682432.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">20</span>
#
# <span class="fc8 sc0">834973696.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">36/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">4ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">8421891584.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">19</span>
#
# <span class="fc8 sc0">097423872.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">37/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">4ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">7558081024.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">19</span>
#
# <span class="fc8 sc0">530541056.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">38/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">6951711744.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">18</span>
#
# <span class="fc8 sc0">991861760.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">39/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">6637931008.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">16</span>
#
# <span class="fc8 sc0">955921408.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">40/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">6067017216.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">15</span>
#
# <span class="fc8 sc0">321756672.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">41/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">5854266880.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">14</span>
#
# <span class="fc8 sc0">848336896.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">42/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">5741652992.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">13</span>
#
# <span class="fc8 sc0">548585984.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">43/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">5499480064.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">13</span>
#
# <span class="fc8 sc0">736945664.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">44/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">5346961408.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">13</span>
#
# <span class="fc8 sc0">284270080.0000</span>
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">45/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">4ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">5179998720.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">12</span>
#
# <span class="fc8 sc0">758976512.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">46/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">5294595072.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">12</span>
#
# <span class="fc8 sc0">697150464.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">47/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">5125353472.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">11</span>
#
# <span class="fc8 sc0">694658560.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">48/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">5200043520.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">97</span>
#
# <span class="fc8 sc0">71138048.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">49/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">5213671936.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">94</span>
#
# <span class="fc8 sc0">03393024.0000</span>
#
# <span class="fc8 sc0">Epoch </span><span class="fc8 sc0">50/50</span>
#
# <span class="fc8 sc0">349/349 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">3ms/step </span><span class="fc8 sc0">- </span><span
# class="fc8 sc0">loss: </span><span class="fc8 sc0">5141705728.0000
# </span><span class="fc8 sc0">- </span><span class="fc8 sc0">val_loss:
# </span><span class="fc8 sc0">10</span>
#
# <span class="fc8 sc0">682987520.0000</span>
#
# <span class="fc8 sc0">109/109 </span><span
# class="fc8 sc0">\[==============================\] </span><span
# class="fc8 sc0">- </span><span class="fc8 sc0">1s </span><span
# class="fc8 sc0">1ms/step</span>
#
# <span class="fc8 sc0">Mean </span><span class="fc8 sc0">Squared
# </span><span class="fc8 sc0">Error: </span><span
# class="fc8 sc0">10499794813.146599</span>
#
# <span class="fc8 sc0">R-squared: </span><span
# class="fc8 sc0">-0.1518082573703612</span>
#
# <span
# class="fc8 sc0">C:\Users\sumit\anaconda3\lib\site-packages\sklearn\linear_model\\\_coordinate_descent.py:628:
# </span><span class="fc8 sc0">C</span>
#
# <span class="fc8 sc0">onvergenceWarning: </span><span
# class="fc8 sc0">Objective </span><span class="fc8 sc0">did </span><span
# class="fc8 sc0">not </span><span class="fc8 sc0">converge. </span><span
# class="fc8 sc0">You </span><span class="fc8 sc0">might </span><span
# class="fc8 sc0">want </span><span class="fc8 sc0">to </span><span
# class="fc8 sc0">increase </span><span class="fc8 sc0">the </span><span
# class="fc8 sc0">number </span><span class="fc8 sc0">of </span><span
# class="fc8 sc0">itera</span>
#
# <span class="fc8 sc0">tions, </span><span class="fc8 sc0">check
# </span><span class="fc8 sc0">the </span><span class="fc8 sc0">scale
# </span><span class="fc8 sc0">of </span><span class="fc8 sc0">the
# </span><span class="fc8 sc0">features </span><span class="fc8 sc0">or
# </span><span class="fc8 sc0">consider </span><span
# class="fc8 sc0">increasing </span><span class="fc8 sc0">regularisation.
# </span><span class="fc8 sc0">Duality </span><span class="fc8 sc0">gap:
# </span><span class="fc8 sc0">4.</span>
#
# <span class="fc8 sc0">345e+12, </span><span class="fc8 sc0">tolerance:
# </span><span class="fc8 sc0">1.269e+10</span>
#
# <span class="fc8 sc0"> </span><span class="fc8 sc0"> </span><span
# class="fc8 sc0">model </span><span class="fc8 sc0">= </span><span
# class="fc8 sc0">cd_fast.enet_coordinate_descent(</span>
#
# <span class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">rain_R2</span><span class="_ _26"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_R2</span><span class="_ _2c"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_MSE</span><span class="_ _2d"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_RMSE</span><span class="_ _2e"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_MAE</span>
#
# <span class="fc8 sc0">Lasso</span><span class="_ _0"> </span><span
# class="ff2"><span class="fc8 sc0">0.585009</span><span class="_ _0">
# </span><span class="fc8 sc0">0.588948</span><span class="_ _0">
# </span><span class="fc8 sc0">3.747114e+09</span><span class="_ _0">
# </span><span class="fc8 sc0">61213.678646</span><span class="_ _0">
# </span><span class="fc8 sc0">46199.161283</span></span>
#
# <span class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">rain_R2</span><span class="_ _26"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_R2</span><span class="_ _2c"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_MSE</span><span class="_ _2d"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_RMSE</span><span class="_ _2e"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_MAE</span>
#
# <span class="fc8 sc0">Ridge</span><span class="_ _0"> </span><span
# class="ff2"><span class="fc8 sc0">0.584982</span><span class="_ _0">
# </span><span class="fc8 sc0">0.588941</span><span class="_ _0">
# </span><span class="fc8 sc0">3.747182e+09</span><span class="_ _0">
# </span><span class="fc8 sc0">61214.231846</span><span class="_ _0">
# </span><span class="fc8 sc0">46202.274281</span></span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[45\]:</span>
#
# from<span class="ff3 fc3"> sklearn.linear_model </span>import<span
# class="ff3 fc3"> Ridge<span class="fc4">,</span> Lasso</span>
#
# lasso <span class="ff4 fc6">=</span> Lasso<span
# class="fc4">(</span>alpha<span class="ff4 fc6">=</span><span
# class="fc9">1.0<span class="fc4">)</span></span>
#
# lasso<span class="ff4 fc6">.</span>fit<span
# class="fc4">(</span>x_train<span class="fc4">,</span> y_train<span
# class="fc4">)</span>
#
# y_pred_lasso <span class="ff4 fc6">=</span> lasso<span
# class="ff4 fc6">.</span>predict<span class="fc4">(</span>x_test<span
# class="fc4">)</span>
#
# lasso_df <span class="ff4 fc6">=</span> model_instantiation<span
# class="fc4">(</span>lasso<span class="fc4">,</span> x_train<span
# class="fc4">,</span> x_test<span class="fc4">,</span> y_train<span
# class="fc4">,</span> y_test<span class="fc4">,</span> y_pred_lasso<span
# class="fc4">,</span> <span class="fc7">'Lasso'</span>
#
# lasso_df
#
# <span class="fc8 sc0">Out\[45\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[46\]:</span>
#
# ridge <span class="ff4 fc6">=</span> Ridge<span
# class="fc4">(</span>alpha<span class="ff4 fc6">=</span><span
# class="fc9">1.0<span class="fc4">)</span></span>
#
# ridge<span class="ff4 fc6">.</span>fit<span
# class="fc4">(</span>x_train<span class="fc4">,</span> y_train<span
# class="fc4">)</span>
#
# y_pred_ridge <span class="ff4 fc6">=</span> ridge<span
# class="ff4 fc6">.</span>predict<span class="fc4">(</span>x_test<span
# class="fc4">)</span>
#
# ridge_df <span class="ff4 fc6">=</span> model_instantiation<span
# class="fc4">(</span>ridge<span class="fc4">,</span> x_train<span
# class="fc4">,</span> x_test<span class="fc4">,</span> y_train<span
# class="fc4">,</span> y_test<span class="fc4">,</span> y_pred_ridge<span
# class="fc4">,</span> <span class="fc7">'Ridge'</span>
#
# ridge_df
#
# <span class="fc8 sc0">Out\[46\]:</span>
#
# <span class="fc8 sc0">In </span><span class="fc8 sc0">\[47\]:</span>
#
# all_results <span class="ff4 fc6">=</span> pd<span
# class="ff4 fc6">.</span>concat<span class="fc4">(\[</span>LR_df<span
# class="fc4">,</span>DT_df<span class="fc4">,</span>RF_df<span
# class="fc4">,</span>RF_df_2<span class="fc4">,</span>ada_df<span
# class="fc4">,</span>xgboost_df<span class="fc4">,</span>lasso_df<span
# class="fc4">,</span>ridge_df<span class="fc4">\])</span>
#
# all_results
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# <span class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">rain_R2</span><span class="_ _26"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_R2</span><span class="_ _2c"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_MSE</span><span class="_ _2d"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_RMSE</span><span class="_ _2e"> </span><span
# class="fc8 sc0">T</span><span class="_ _22"></span><span
# class="fc8 sc0">est_MAE</span>
#
# <span class="fc8 sc0">Linear </span><span class="fc8 sc0">R</span><span
# class="fc8 sc0">egr</span><span class="_ _23"></span><span
# class="fc8 sc0">ession</span><span class="_ _0"> </span><span
# class="ff2"><span class="fc8 sc0">0.630962</span><span class="_ _0">
# </span><span class="fc8 sc0">0.624499</span><span class="_ _2f">
# </span><span class="fc8 sc0">1.071205e-01</span><span class="_ _16">
# </span><span class="fc8 sc0">0.327293</span><span class="_ _16">
# </span><span class="fc8 sc0">0.251028</span></span>
#
# <span class="fc8 sc0">D</span><span class="_ _1e"></span><span
# class="fc8 sc0">T</span><span class="_ _1e"></span><span
# class="fc8 sc0">r</span><span class="fc8 sc0">ee_R</span><span
# class="fc8 sc0">egr</span><span class="fc8 sc0">ession</span><span
# class="_ _0"> </span><span class="ff2"><span
# class="fc8 sc0">0.763267</span><span class="_ _0"> </span><span
# class="fc8 sc0">0.717443</span><span class="_ _2f"> </span><span
# class="fc8 sc0">8.060598e-02</span><span class="_ _16"> </span><span
# class="fc8 sc0">0.283912</span><span class="_ _16"> </span><span
# class="fc8 sc0">0.208418</span></span>
#
# <span class="fc8 sc0">RF_R</span><span class="fc8 sc0">egr</span><span
# class="_ _23"></span><span class="fc8 sc0">ession</span><span
# class="_ _0"> </span><span class="ff2"><span
# class="fc8 sc0">0.850595</span><span class="_ _0"> </span><span
# class="fc8 sc0">0.774959</span><span class="_ _2f"> </span><span
# class="fc8 sc0">6.419829e-02</span><span class="_ _16"> </span><span
# class="fc8 sc0">0.253374</span><span class="_ _16"> </span><span
# class="fc8 sc0">0.180186</span></span>
#
# <span class="fc8 sc0">RF2_R</span><span class="fc8 sc0">egr</span><span
# class="_ _23"></span><span class="fc8 sc0">ession</span><span
# class="_ _0"> </span><span class="ff2"><span
# class="fc8 sc0">0.830124</span><span class="_ _0"> </span><span
# class="fc8 sc0">0.763076</span><span class="_ _2f"> </span><span
# class="fc8 sc0">6.758802e-02</span><span class="_ _16"> </span><span
# class="fc8 sc0">0.259977</span><span class="_ _16"> </span><span
# class="fc8 sc0">0.186851</span></span>
#
# <span class="fc8 sc0">AD</span><span class="fc8 sc0">A_R</span><span
# class="_ _1e"></span><span class="fc8 sc0">egr</span><span
# class="fc8 sc0">ession</span><span class="_ _0"> </span><span
# class="ff2"><span class="fc8 sc0">0.599874</span><span class="_ _0">
# </span><span class="fc8 sc0">0.586475</span><span class="_ _2f">
# </span><span class="fc8 sc0">1.179678e-01</span><span class="_ _16">
# </span><span class="fc8 sc0">0.343464</span><span class="_ _16">
# </span><span class="fc8 sc0">0.271343</span></span>
#
# <span class="fc8 sc0">X</span><span class="fc8 sc0">GB_R</span><span
# class="_ _1e"></span><span class="fc8 sc0">egr</span><span
# class="fc8 sc0">ession</span><span class="_ _0"> </span><span
# class="ff2"><span class="fc8 sc0">0.923149</span><span class="_ _0">
# </span><span class="fc8 sc0">0.801669</span><span class="_ _2f">
# </span><span class="fc8 sc0">5.657852e-02</span><span class="_ _16">
# </span><span class="fc8 sc0">0.237862</span><span class="_ _16">
# </span><span class="fc8 sc0">0.163638</span></span>
#
# <span class="fc8 sc0">Lasso</span><span class="_ _0"> </span><span
# class="ff2"><span class="fc8 sc0">0.585009</span><span class="_ _0">
# </span><span class="fc8 sc0">0.588948</span><span class="_ _0">
# </span><span class="fc8 sc0">3.747114e+09</span><span class="_ _0">
# </span><span class="fc8 sc0">61213.678646</span><span class="_ _0">
# </span><span class="fc8 sc0">46199.161283</span></span>
#
# <span class="fc8 sc0">Ridge</span><span class="_ _0"> </span><span
# class="ff2"><span class="fc8 sc0">0.584982</span><span class="_ _0">
# </span><span class="fc8 sc0">0.588941</span><span class="_ _0">
# </span><span class="fc8 sc0">3.747182e+09</span><span class="_ _0">
# </span><span class="fc8 sc0">61214.231846</span><span class="_ _0">
# </span><span class="fc8 sc0">46202.274281</span></span>
#
# <span class="fc8 sc0">Out\[47\]:</span>
#
# ![](data:image/png;base64,...)
